# %%
import re

p = re.compile('[☝️]*')
p.match('☝️☝️☺️☝️')
# Out:
# <re.Match object; span=(0, 4), match='☝️☝️'>

# %%
get_first_match_string(r"\{")  # '{'
get_first_match_string(r"[A-Z]") # 'H'
get_first_match_string(r"xyz|XYZ") # 'xyz'
